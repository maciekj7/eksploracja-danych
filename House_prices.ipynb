# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", palette="pastel", font_scale=1.1)
plt.rcParams['figure.figsize'] = (10, 6)

df = pd.read_csv("train.csv")

print("🔹 Rozmiar danych:", df.shape)
print("\n🔹 Pierwsze 5 wierszy:")
display(df.head())

print("\n🔹 Typy danych:")
display(df.dtypes.value_counts())

print("\n🔹 Podstawowe statystyki opisowe (dla zmiennych numerycznych):")
display(df.describe())

target = 'SalePrice'

print("\nPodstawowe statystyki zmiennej docelowej:")
print(df[target].describe())
print("\nMediana ceny:", df[target].median())
print("Średnia cena:", df[target].mean())

plt.figure(figsize=(10,6))
sns.histplot(df[target], bins=30, kde=True)
plt.title("Rozkład cen domów (SalePrice)")
plt.xlabel("Cena")
plt.ylabel("Liczba domów")
plt.show()

plt.figure(figsize=(10,4))
sns.boxplot(x=df[target])
plt.title("Boxplot cen domów")
plt.xlabel("Cena")
plt.show()

skew_val = df[target].skew()
print(f"Skośność rozkładu cen: {skew_val:.2f}")
if skew_val > 1:
    print("Rozkład jest prawoskośny (dużo tanich domów, mało bardzo drogich).")
elif skew_val < -1:
    print("Rozkład jest lewoskośny (dużo drogich domów, mało tanich).")
else:
    print("Rozkład jest zbliżony do symetrycznego.")

area_cols = [col for col in df.columns if ('Area' in col) or ('SF' in col)]
print("\nKolumny związane z powierzchnią:")
print(area_cols)

corrs = df[area_cols + [target]].corr()[target].sort_values(ascending=False)
print("\nKorelacja powierzchni z ceną:")
display(corrs)

plt.figure(figsize=(10,6))
sns.scatterplot(x='GrLivArea', y='SalePrice', data=df, alpha=0.6)
plt.title("Zależność: powierzchnia mieszkalna (GrLivArea) vs cena")
plt.xlabel("Powierzchnia mieszkalna (stopy kw.)")
plt.ylabel("Cena domu")
plt.show()

plt.figure(figsize=(10,6))
sns.scatterplot(x='LotArea', y='SalePrice', data=df, alpha=0.6, color='orange')
plt.title("Zależność: powierzchnia działki (LotArea) vs cena")
plt.xlabel("Powierzchnia działki")
plt.ylabel("Cena domu")
plt.show()

selected_cols = ['GrLivArea', 'TotalBsmtSF', 'LotArea']

plt.figure(figsize=(10,6))
for col in selected_cols:
    sns.regplot(x=df[col], y=df['SalePrice'], label=col, scatter_kws={'alpha':0.4})
plt.legend()
plt.title("Porównanie wpływu różnych powierzchni na cenę")
plt.xlabel("Powierzchnia (stopy kw.)")
plt.ylabel("Cena domu")
plt.show()

print("""
Wnioski:
1. Zmienna docelowa to 'SalePrice' – cena sprzedaży domu.
2. Rozkład cen jest prawoskośny – większość domów jest w niższej półce cenowej.
3. Występują outliery – bardzo drogie domy (mogą to być luksusowe posiadłości).
4. Powierzchnia mieszkalna (GrLivArea) ma silną korelację z ceną.
5. Powierzchnia działki (LotArea) ma słabszą zależność – duże działki nie zawsze oznaczają wysoką cenę.
""")
# Out:
# 🔹 Rozmiar danych: (1460, 81)
#
# 🔹 Pierwsze 5 wierszy:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
# ...
